# %%
"""Linear Regression with Boston Housing prices dataset
https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html
"""
# Out:
# 'Linear Regression with Boston Housing prices dataset\nhttps://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html\n'

# %%
from sklearn import datasets
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = datasets.load_boston()

# %%
X = data.data
y = data.target

print(X.shape) 
print(len(y))
# Out:
# (506, 13)
# 506

# %%
X[:5]
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, 0.0000e+00, 5.3800e-01,
#         6.5750e+00, 6.5200e+01, 4.0900e+00, 1.0000e+00, 2.9600e+02,
#         1.5300e+01, 3.9690e+02, 4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         6.4210e+00, 7.8900e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9690e+02, 9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#         7.1850e+00, 6.1100e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#         1.7800e+01, 3.9283e+02, 4.0300e+00],
#        [3.2370e-02, 0.0000e+00, 2.1800e+00, 0.0000e+00, 4.5800e-01,
#         6.9980e+00, 4.5800e+01, 6.0622e+00, 3.0000e+00, 2.2200e+02,
#         1.8700e+01, 3.9463e+02, 2.9400e+00],
#        [6.9050e-02, 0.0000e+00, 2.1800e+00, 0.0000e+00, 4.5800e-01,
#         7.1470e+00, 5.4200e+01, 6.0622e+00, 3.0000e+00, 2.2200e+02,
#         1.8700e+01, 3.9690e+02, 5.3300e+00]])

# %%
y[:5]
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2])

# %%
# X[:, 0] = first column selection = same as X.T[0]

plt.scatter(X.T[5], y) # No. of rooms

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
r2 = r2_score(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)

print("R^2 score =", r2)
print("MSE =", mse)
print("MAE =", mae)
# Out:
# R^2 score = 0.6397748287664656
# MSE = 33.48002127377104
# MAE = 3.72515263886957

# %%
print("Coef:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coef: [-9.37243910e-02  3.25654054e-02 -3.45026433e-03  2.54946603e+00
#  -1.46822604e+01  4.11565657e+00 -7.38143072e-03 -1.33429673e+00
#   2.65575587e-01 -1.20400422e-02 -9.02991950e-01  1.01452211e-02
#  -5.20056215e-01]
# Intercept: 31.94944021370338

# %%
feature_num = 7

plt.scatter(X.T[feature_num], y) 
y_line = model.coef_[feature_num] * X.T[feature_num] + model.intercept_
plt.plot(X.T[feature_num], y_line)
plt.show()
